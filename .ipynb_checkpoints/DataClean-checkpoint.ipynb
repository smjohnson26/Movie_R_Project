# %%
import pandas as pd
import requests
import numpy as np
import requests
import bs4
import re
from datetime import datetime
from threading import Timer
import csv
import os

from collections import OrderedDict
from itertools import chain

# %%
movies= pd.read_csv('IMDB movies.csv')
currency= pd.read_csv('Currency.csv')
# Out:
# C:\Users\CAM\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#subset data
budgetmovies= movies[movies['budget'].notnull()]

# %%
#insert currency column into dataframe
budgetmovies['currency']= ""
for row in budgetmovies.index:
    budgetmovies.loc[budgetmovies['budget'].str.contains('$'), 'currency'] == 'USA'
# Out:
# C:\Users\CAM\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#trial code
budgetmovies['Currency'] = re.findall('\w\w\w',budgetmovies['budget'])
budgetmovies['budget'].str.findall('\w\w\w')
budgetmovies.loc[budgetmovies['budget'].str.contains('\w\w\w'), 'currency'] = '\w\w\w'
if '$' in budgetmovies['budget'][row]: 
        budgetmovies['Currency'][row] = "USA"
    else:
        pass

# %%
budgetmovies.head(5)
# Out:
#   imdb_title_id                        title               original_title  \
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 3     tt0002101                    Cleopatra                    Cleopatra
# 7     tt0002445                   Quo Vadis?                   Quo Vadis?
# 8     tt0002452        Independenta Romaniei        Independenta Romaniei
# 9     tt0002461                  Richard III                  Richard III
#
#    year date_published                    genre  duration      country  \
# 1  1906     1906-12-26  Biography, Crime, Drama        70    Australia
# 3  1912     1912-11-13           Drama, History       100          USA
# 7  1913     1913-03-01           Drama, History       120        Italy
# 8  1912     1912-09-01             History, War       120      Romania
# 9  1912     1912-10-15                    Drama        55  France, USA
#
#   language                               director  ...  \
# ...
